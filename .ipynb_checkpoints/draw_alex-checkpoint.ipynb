# %%
"""
Draw a graph of the net architecture.
"""
from argparse import ArgumentParser, ArgumentDefaultsHelpFormatter
from google.protobuf import text_format

import caffe
import caffe.draw
from caffe.proto import caffe_pb2
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

def parse_args():
    """Parse input arguments
    """

    parser = ArgumentParser(description=__doc__,
                            formatter_class=ArgumentDefaultsHelpFormatter)

    #parser.add_argument('input_net_proto_file',
    #                    help='Input network prototxt file')
    #parser.add_argument('output_image_file',
    #                    help='Output image file')
    parser.add_argument('--rankdir',
                        help=('One of TB (top-bottom, i.e., vertical), '
                              'RL (right-left, i.e., horizontal), or another '
                              'valid dot option; see '
                              'http://www.graphviz.org/doc/info/'
                              'attrs.html#k:rankdir'),
                        default='LR')
    parser.add_argument('--phase',
                        help=('Which network phase to draw: can be TRAIN, '
                              'TEST, or ALL.  If ALL, then all layers are drawn '
                              'regardless of phase.'),
                        default="ALL")

    args = parser.parse_args()
    return args

class args_cls(object):
    def __init__(self):
        self.input_net_proto_file = '/home/ocean1101/Workspace/ssd/caffe/examples/AlexNet/cifar10/train_val.prototxt'
        self.phase = "TRAIN"
        '''
        rankdir : {'LR', 'TB', 'BT'}
        Direction of graph layout.
        '''
        self.rankdir = "TB"
        self.output_image_file = 'netimg.png'
        
def main():
    #args = parse_args()
    args = args_cls()
    net = caffe_pb2.NetParameter()
    text_format.Merge(open(args.input_net_proto_file).read(), net)
    #print('Drawing net to %s' % args.output_image_file)
    phase=None;
    if args.phase == "TRAIN":
        phase = caffe_pb2.TRAIN
    elif args.phase == "TEST":
        phase = caffe_pb2.TEST
    elif args.phase != "ALL":
        raise ValueError("Unknown phase: " + args.phase)
    caffe.draw.draw_net_to_file(net, args.output_image_file, args.rankdir,
                                phase)
    #print net, args.rankdir, phase
    #graph = caffe.draw.draw_net_to_file(net, args.rankdir, phase=phase)
    #img=Image.frombytes('RGB',sizeof(graph),graph)
    img = Image.open(args.output_image_file)
    
    print img.format,img.size, img.mode
    #import pdb;pdb.set_trace()
    
    img = np.array(img)
    plt.figure(figsize=(100,200))
    plt.imshow(img)#,aspect='auto')
    plt.show()

if __name__ == '__main__':
    main()
# Out:
# > /usr/local/lib/python2.7/dist-packages/pydot.py(1985)create()
# -> cmdline = [self.progs[prog], '-T'+format, tmp_name] + args

# %%
from __future__ import print_function
from caffe import layers as L, params as P, to_proto

def conv_bn_relu(bottom, kernel_size, num_output, stride=1, pad=0, group=1):
    conv = L.Convolution(bottom, kernel_size=kernel_size, stride=stride,
                                num_output=num_output, pad=pad, group=group,
                                weight_filler=dict(type='xavier'),
                                bias_filler=dict(type='constant', value=0))
    bn = L.BatchNorm(conv, use_global_stats=False)
    scale = L.Scale(bn, bias_term=True)
    relu = L.ReLU(scale, in_place=True)
    return conv, relu
#global average pooling
def fc_gav(bottom):
    #fc = L.InnerProduct(bottom, num_output=num_output)
    fc = L.Pooling(bottom, pool=P.Pooling.AVE, kernel_size=6, stride=1)
    bn = L.BatchNorm(fc, use_global_stats=False)
    scale = L.Scale(bn, bias_term=True)
    relu = L.ReLU(scale, in_place=True)
    drop = L.Dropout(relu, dropout_ratio=0.5)
    return drop

def max_pool(bottom, kernel_size, stride=2):
    return L.Pooling(bottom, pool=P.Pooling.MAX, kernel_size=kernel_size, stride=stride)

def mynet(lmdb, batch_size=256, include_acc=False):
    name = L.Name='xxx'
    # data layer
    data, label = L.Data(name, source=lmdb, backend=P.Data.LMDB, batch_size=batch_size, ntop=2,
        transform_param=dict(crop_size=227, mean_value=[104, 117, 123], mirror=True))
    # the net itself
    #import pdb;pdb.set_trace()
    
    conv1, relu1 = conv_bn_relu(data, 3, 96, stride=1, pad=2)
    
    norm1 = L.LRN(relu1, local_size=5, alpha=1e-4, beta=0.75)
    pool1 = max_pool(norm1, 3, stride=2)
    conv2, relu2 = conv_bn_relu(pool1, 3, 128, stride=1, pad=2, group=2)
    norm2 = L.LRN(relu2, local_size=5, alpha=1e-4, beta=0.75)
    pool2 = max_pool(norm2, 3, stride=2)
    
    conv3, relu3 = conv_bn_relu(pool2, 3, 256, pad=2)
    
    conv4, relu4 = conv_bn_relu(relu3, 3, 384, pad=1, group=2)
    conv5, relu5 = conv_bn_relu(relu4, 3, 256, pad=1, group=2)
    
    pool5 = max_pool(relu5, 3, stride=2)
    
    fc7 = fc_gav(pool5)
    #fc8 = L.InnerProduct(fc7, num_output=10, kernel_size=1, stride=1,
    #    weight_filler=dict(type='xavier'), bias_filler=dict(type='constant',value=0))
    ''''''
    fc8 = L.Convolution(fc7, kernel_size=1, num_output=10,stride=1,
            weight_filler=dict(type='xavier'),
            bias_filler=dict(type='constant',value=0))
    
    acc = L.Accuracy(fc8, label)
    loss = L.SoftmaxWithLoss(fc8, label)
    return to_proto(loss, acc)

def make_net():
    #with open('train_val1.prototxt','w') as f:
        #print(mynet('123'), file=f)
    print(mynet('123'))

if __name__ == '__main__':
    make_net()
# Out:
# <type 'str'>
# Data
# test in layer_fn
# name: Data  args: () kwargs: {'source': '123', 'ntop': 2, 'transform_param': {'mean_value': [104, 117, 123], 'mirror': True, 'crop_size': 227}, 'batch_size': 256, 'backend': 1}
# <type 'str'>
# Convolution
# test in layer_fn
# name: Convolution  args: (<caffe.net_spec.Top object at 0x7f50d1e47390>,) kwargs: {'group': 1, 'num_output': 96, 'weight_filler': {'type': 'xavier'}, 'stride': 1, 'pad': 2, 'bias_filler': {'type': 'constant', 'value': 0}, 'kernel_size': 3}
# <type 'str'>
# BatchNorm
# test in layer_fn
# name: BatchNorm  args: (<caffe.net_spec.Top object at 0x7f50d1d3ec50>,) kwargs: {'use_global_stats': False}
# <type 'str'>
# Scale
# test in layer_fn
# name: Scale  args: (<caffe.net_spec.Top object at 0x7f50d1d3edd0>,) kwargs: {'bias_term': True}
# <type 'str'>
# ReLU
# test in layer_fn
# name: ReLU  args: (<caffe.net_spec.Top object at 0x7f50d1d3ee90>,) kwargs: {'in_place': True}
# <type 'str'>
# LRN
# test in layer_fn
# name: LRN  args: (<caffe.net_spec.Top object at 0x7f50d1d3e590>,) kwargs: {'alpha': 0.0001, 'beta': 0.75, 'local_size': 5}
# <type 'str'>
# Pooling
# test in layer_fn
# name: Pooling  args: (<caffe.net_spec.Top object at 0x7f50d1d3eb50>,) kwargs: {'stride': 2, 'kernel_size': 3, 'pool': 0}
# <type 'str'>
# Convolution
# test in layer_fn
# name: Convolution  args: (<caffe.net_spec.Top object at 0x7f50d1d3ead0>,) kwargs: {'group': 2, 'num_output': 128, 'weight_filler': {'type': 'xavier'}, 'stride': 1, 'pad': 2, 'bias_filler': {'type': 'constant', 'value': 0}, 'kernel_size': 3}
# <type 'str'>
# BatchNorm
# test in layer_fn
# name: BatchNorm  args: (<caffe.net_spec.Top object at 0x7f50d1d3ec90>,) kwargs: {'use_global_stats': False}
# <type 'str'>
# Scale
# test in layer_fn
# name: Scale  args: (<caffe.net_spec.Top object at 0x7f50d1d3ec10>,) kwargs: {'bias_term': True}
# <type 'str'>
# ReLU
# test in layer_fn
# name: ReLU  args: (<caffe.net_spec.Top object at 0x7f50d1d3e9d0>,) kwargs: {'in_place': True}
# <type 'str'>
# LRN
# test in layer_fn
# name: LRN  args: (<caffe.net_spec.Top object at 0x7f50d1d3e8d0>,) kwargs: {'alpha': 0.0001, 'beta': 0.75, 'local_size': 5}
# <type 'str'>
# Pooling
# test in layer_fn
# name: Pooling  args: (<caffe.net_spec.Top object at 0x7f50d1d3e690>,) kwargs: {'stride': 2, 'kernel_size': 3, 'pool': 0}
# <type 'str'>
# Convolution
# test in layer_fn
# name: Convolution  args: (<caffe.net_spec.Top object at 0x7f50d1d3eed0>,) kwargs: {'group': 1, 'num_output': 256, 'weight_filler': {'type': 'xavier'}, 'stride': 1, 'pad': 2, 'bias_filler': {'type': 'constant', 'value': 0}, 'kernel_size': 3}
# <type 'str'>
# BatchNorm
# test in layer_fn
# name: BatchNorm  args: (<caffe.net_spec.Top object at 0x7f50d1d3e5d0>,) kwargs: {'use_global_stats': False}
# <type 'str'>
# Scale
# test in layer_fn
# name: Scale  args: (<caffe.net_spec.Top object at 0x7f50d1eb7d10>,) kwargs: {'bias_term': True}
# <type 'str'>
# ReLU
# test in layer_fn
# name: ReLU  args: (<caffe.net_spec.Top object at 0x7f50d1eb7b90>,) kwargs: {'in_place': True}
# <type 'str'>
# Convolution
# test in layer_fn
# name: Convolution  args: (<caffe.net_spec.Top object at 0x7f50d1eb7fd0>,) kwargs: {'group': 2, 'num_output': 384, 'weight_filler': {'type': 'xavier'}, 'stride': 1, 'pad': 1, 'bias_filler': {'type': 'constant', 'value': 0}, 'kernel_size': 3}
# <type 'str'>
# BatchNorm
# test in layer_fn
# name: BatchNorm  args: (<caffe.net_spec.Top object at 0x7f50d1eb7790>,) kwargs: {'use_global_stats': False}
# <type 'str'>
# Scale
# test in layer_fn
# name: Scale  args: (<caffe.net_spec.Top object at 0x7f50d1eb7e10>,) kwargs: {'bias_term': True}
# <type 'str'>
# ReLU
# test in layer_fn
# name: ReLU  args: (<caffe.net_spec.Top object at 0x7f50d1d8f0d0>,) kwargs: {'in_place': True}
# <type 'str'>
# Convolution
# test in layer_fn
# name: Convolution  args: (<caffe.net_spec.Top object at 0x7f50d1d77390>,) kwargs: {'group': 2, 'num_output': 256, 'weight_filler': {'type': 'xavier'}, 'stride': 1, 'pad': 1, 'bias_filler': {'type': 'constant', 'value': 0}, 'kernel_size': 3}
# <type 'str'>
# BatchNorm
# test in layer_fn
# name: BatchNorm  args: (<caffe.net_spec.Top object at 0x7f50d1d77b10>,) kwargs: {'use_global_stats': False}
# <type 'str'>
# Scale
# test in layer_fn
# name: Scale  args: (<caffe.net_spec.Top object at 0x7f50d1d77bd0>,) kwargs: {'bias_term': True}
# <type 'str'>
# ReLU
# test in layer_fn
# name: ReLU  args: (<caffe.net_spec.Top object at 0x7f50d1d77310>,) kwargs: {'in_place': True}
# <type 'str'>
# Pooling
# test in layer_fn
# name: Pooling  args: (<caffe.net_spec.Top object at 0x7f50d1d77110>,) kwargs: {'stride': 2, 'kernel_size': 3, 'pool': 0}
# <type 'str'>
# Pooling
# test in layer_fn
# name: Pooling  args: (<caffe.net_spec.Top object at 0x7f50d1d77fd0>,) kwargs: {'stride': 1, 'kernel_size': 6, 'pool': 1}
# <type 'str'>
# BatchNorm
# test in layer_fn
# name: BatchNorm  args: (<caffe.net_spec.Top object at 0x7f50d1d77050>,) kwargs: {'use_global_stats': False}
# <type 'str'>
# Scale
# test in layer_fn
# name: Scale  args: (<caffe.net_spec.Top object at 0x7f50d1d77090>,) kwargs: {'bias_term': True}
# <type 'str'>
# ReLU
# test in layer_fn
# name: ReLU  args: (<caffe.net_spec.Top object at 0x7f50d1d776d0>,) kwargs: {'in_place': True}
# <type 'str'>
# Dropout
# test in layer_fn
# name: Dropout  args: (<caffe.net_spec.Top object at 0x7f50d1d779d0>,) kwargs: {'dropout_ratio': 0.5}
# <type 'str'>
# Convolution
# test in layer_fn
# name: Convolution  args: (<caffe.net_spec.Top object at 0x7f50d1d77f50>,) kwargs: {'weight_filler': {'type': 'xavier'}, 'stride': 1, 'bias_filler': {'type': 'constant', 'value': 0}, 'num_output': 10, 'kernel_size': 1}
# <type 'str'>
# Accuracy
# test in layer_fn
# name: Accuracy  args: (<caffe.net_spec.Top object at 0x7f50d1d77c10>, <caffe.net_spec.Top object at 0x7f50d1e47e50>) kwargs: {}
# <type 'str'>
# SoftmaxWithLoss
# test in layer_fn
# name: SoftmaxWithLoss  args: (<caffe.net_spec.Top object at 0x7f50d1d77c10>, <caffe.net_spec.Top object at 0x7f50d1e47e50>) kwargs: {}
# layer {
#   name: "Data1"
#   type: "Data"
#   top: "Data1"
#   top: "Data2"
#   transform_param {
#     mirror: true
#     crop_size: 227
#     mean_value: 104
#     mean_value: 117
#     mean_value: 123
#   }
#   data_param {
#     source: "123"
#     batch_size: 256
#     backend: LMDB
#   }
# }
# layer {
#   name: "Convolution1"
#   type: "Convolution"
#   bottom: "Data1"
#   top: "Convolution1"
#   convolution_param {
#     num_output: 96
#     pad: 2
#     kernel_size: 3
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "BatchNorm1"
#   type: "BatchNorm"
#   bottom: "Convolution1"
#   top: "BatchNorm1"
#   batch_norm_param {
#     use_global_stats: false
#   }
# }
# layer {
#   name: "Scale1"
#   type: "Scale"
#   bottom: "BatchNorm1"
#   top: "Scale1"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "ReLU1"
#   type: "ReLU"
#   bottom: "Scale1"
#   top: "Scale1"
# }
# layer {
#   name: "LRN1"
#   type: "LRN"
#   bottom: "Scale1"
#   top: "LRN1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "Pooling1"
#   type: "Pooling"
#   bottom: "LRN1"
#   top: "Pooling1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "Convolution2"
#   type: "Convolution"
#   bottom: "Pooling1"
#   top: "Convolution2"
#   convolution_param {
#     num_output: 128
#     pad: 2
#     kernel_size: 3
#     group: 2
#     stride: 1
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "BatchNorm2"
#   type: "BatchNorm"
#   bottom: "Convolution2"
#   top: "BatchNorm2"
#   batch_norm_param {
#     use_global_stats: false
#   }
# }
# layer {
#   name: "Scale2"
#   type: "Scale"
#   bottom: "BatchNorm2"
#   top: "Scale2"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "ReLU2"
#   type: "ReLU"
#   bottom: "Scale2"
#   top: "Scale2"
# }
# layer {
#   name: "LRN2"
#   type: "LRN"
#   bottom: "Scale2"
#   top: "LRN2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "Pooling2"
#   type: "Pooling"
#   bottom: "LRN2"
#   top: "Pooling2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "Convolution3"
#   type: "Convolution"
#   bottom: "Pooling2"
#   top: "Convolution3"
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 3
#     group: 1
#     stride: 1
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "BatchNorm3"
#   type: "BatchNorm"
#   bottom: "Convolution3"
#   top: "BatchNorm3"
#   batch_norm_param {
#     use_global_stats: false
#   }
# }
# layer {
#   name: "Scale3"
#   type: "Scale"
#   bottom: "BatchNorm3"
#   top: "Scale3"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "ReLU3"
#   type: "ReLU"
#   bottom: "Scale3"
#   top: "Scale3"
# }
# layer {
#   name: "Convolution4"
#   type: "Convolution"
#   bottom: "Scale3"
#   top: "Convolution4"
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     stride: 1
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "BatchNorm4"
#   type: "BatchNorm"
#   bottom: "Convolution4"
#   top: "BatchNorm4"
#   batch_norm_param {
#     use_global_stats: false
#   }
# }
# layer {
#   name: "Scale4"
#   type: "Scale"
#   bottom: "BatchNorm4"
#   top: "Scale4"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "ReLU4"
#   type: "ReLU"
#   bottom: "Scale4"
#   top: "Scale4"
# }
# layer {
#   name: "Convolution5"
#   type: "Convolution"
#   bottom: "Scale4"
#   top: "Convolution5"
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     stride: 1
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "BatchNorm5"
#   type: "BatchNorm"
#   bottom: "Convolution5"
#   top: "BatchNorm5"
#   batch_norm_param {
#     use_global_stats: false
#   }
# }
# layer {
#   name: "Scale5"
#   type: "Scale"
#   bottom: "BatchNorm5"
#   top: "Scale5"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "ReLU5"
#   type: "ReLU"
#   bottom: "Scale5"
#   top: "Scale5"
# }
# layer {
#   name: "Pooling3"
#   type: "Pooling"
#   bottom: "Scale5"
#   top: "Pooling3"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "Pooling4"
#   type: "Pooling"
#   bottom: "Pooling3"
#   top: "Pooling4"
#   pooling_param {
#     pool: AVE
#     kernel_size: 6
#     stride: 1
#   }
# }
# layer {
#   name: "BatchNorm6"
#   type: "BatchNorm"
#   bottom: "Pooling4"
#   top: "BatchNorm6"
#   batch_norm_param {
#     use_global_stats: false
#   }
# }
# layer {
#   name: "Scale6"
#   type: "Scale"
#   bottom: "BatchNorm6"
#   top: "Scale6"
#   scale_param {
#     bias_term: true
#   }
# }
# layer {
#   name: "ReLU6"
#   type: "ReLU"
#   bottom: "Scale6"
#   top: "Scale6"
# }
# layer {
#   name: "Dropout1"
#   type: "Dropout"
#   bottom: "Scale6"
#   top: "Dropout1"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "Convolution6"
#   type: "Convolution"
#   bottom: "Dropout1"
#   top: "Convolution6"
#   convolution_param {
#     num_output: 10
#     kernel_size: 1
#     stride: 1
#     weight_filler {
#       type: "xavier"
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "SoftmaxWithLoss1"
#   type: "SoftmaxWithLoss"
#   bottom: "Convolution6"
#   bottom: "Data2"
#   top: "SoftmaxWithLoss1"
# }
# layer {
#   name: "Accuracy1"
#   type: "Accuracy"
#   bottom: "Convolution6"
#   bottom: "Data2"
#   top: "Accuracy1"
# }
